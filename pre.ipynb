# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
data =pd.read_csv('./Datasets/mobile.csv')

# %%
purchase =data[data['Purchased']==1]
not_purchase =data[data['Purchased']==0]

# %%
plt.scatter(purchase['Age'],purchase['EstimatedSalary'],color='blue',label='Purchased')
plt.scatter(not_purchase['Age'],not_purchase['EstimatedSalary'],color='red',label='Not Purchased')

# %%
scaler = MinMaxScaler()
x_scaler =scaler.fit_transform(x)

# %%
x_train,x_test,y_train,y_test =train_test_split(x_scaler,y,test_size=0.2,random_state=42)

# %%
model= KNeighborsClassifier(n_neighbors=5)
model.fit(x_train,y_train)
# Out:
# c:\Users\rajsi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
y_pred =model.predict(x_test)
print("Accuracy:",accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.925

# %%
age = 30
salary = 60000
new_data = scaler.transform([[age, salary]])

prediction = model.predict(new_data)

if prediction == 1:
    print("Customer will purchase mobile")
else:
    print("Customer will NOT purchase mobile")
# Out:
# Customer will NOT purchase mobile
# c:\Users\rajsi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

data = pd.read_csv("./Datasets/computers.csv")

# Check dataset
print("Rows:", data.shape[0])
print("Columns:", data.shape[1])
print("Column Names:", data.columns)

# First column as X
X = data.iloc[:,0:1]

# Second column as Y
y = data.iloc[:,1]

# Model
model = LinearRegression()
model.fit(X,y)

print("Intercept:",model.intercept_)
print("Coefficient:",model.coef_)

# Prediction
y_pred = model.predict(X)

# Plot
plt.scatter(X,y)
plt.plot(X,y_pred)
plt.xlabel("Units")
plt.ylabel("Target")
plt.title("Linear Regression")
plt.show()

# Accuracy
print("R2 Score:",r2_score(y,y_pred))
# Out:
# Rows: 14
# Columns: 2
# Column Names: Index(['Units', 'Minutes'], dtype='object')
# Intercept: 4.161654135338296
# Coefficient: [15.50877193]
# R2 Score: 0.9874371980620736
